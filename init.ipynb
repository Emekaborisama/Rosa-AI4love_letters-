# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting markovify
#   Downloading markovify-0.9.0.tar.gz (27 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (1.19.5)
# Requirement already satisfied: nltk in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 4)) (3.5)
# Collecting flask
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Collecting Flask_Cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting unidecode
#   Downloading Unidecode-1.2.0-py2.py3-none-any.whl (241 kB)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 2)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: regex in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 4)) (2020.11.13)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 4)) (7.1.2)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 4)) (4.56.0)
# Requirement already satisfied: Werkzeug>=0.15 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from flask->-r ./requirements.txt (line 5)) (1.0.1)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from flask->-r ./requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied: Six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Flask_Cors->-r ./requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask->-r ./requirements.txt (line 5)) (1.1.1)
# Building wheels for collected packages: markovify
#   Building wheel for markovify (setup.py): started
#   Building wheel for markovify (setup.py): finished with status 'done'
#   Created wheel for markovify: filename=markovify-0.9.0-py3-none-any.whl size=18476 sha256=1b7f58187f41a7aa0f978f3cdcfefd0365180ec4e25b85af655e66840397ed56
#   Stored in directory: /root/.cache/pip/wheels/fc/af/6c/bc21bf6d1762e7935d15d3c9786022624c49fe64484e1bae9f
# Successfully built markovify
# Installing collected packages: unidecode, markovify, itsdangerous, flask, Flask-Cors
# Successfully installed Flask-Cors-3.0.10 flask-1.1.2 itsdangerous-1.1.0 markovify-0.9.0 unidecode-1.2.0
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1847666d-1024-4ccd-aa0a-538596f06c6f' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
