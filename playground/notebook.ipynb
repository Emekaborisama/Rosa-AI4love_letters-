# %%
import markovify as mk
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize as sent_tok
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
file_name = "letter.txt"

with open('letter.txt') as f:
  data =f.readlines()

# %%
generator_a = mk.Text(data)
print(generator_a.make_sentence())
# Out:
# And I feel like a diamond and will never leave your side.

# %%
for i in range(5):
    print(generator_a.make_sentence())
# Out:
# As I´ve said everything reminds me of you in it and that we’re all doomed and that oblivion is inevitable, and that there is nothing that can describe the feelings within me for you matter to me is priceless.
# The reality that you will always love you as I’ve always done, because being with you or caused you pain.
# I believe in love with you.
# There’s something about the way you would hold me and hug me when I say this from the bottom of my life.
# Sometimes I get to feel as though it is more heavily weighted in some areas than in others.

# %%
sonnets_model = mk.NewlineText(data, state_size=2)
for i in range(10):
    print(sonnets_model.make_sentence())
# Out:
# All I craved for is see and make you mine and get to feel your subtle touch; your pretty smile. I miss you every day. Although we remain friends and see each other, all the pain and grief that I made a big mistake, please forgive me if I ever hurt you so much pretty.
# count myself as a partner that’s supportive, understanding, caring and loving.
# Whenever I sit down and alone in thoughts, I feel and I can to make it all okay.
# You may not say it out loud, and I will love you so much to happen. You have given me all that I have wanted is to be loved this tenderly.
# Sometimes I get down and reminisce about you is your faith and trust and I start to worry, I get caught up with life issues and I aging gracefully together and yet here I am constantly having you in the dictionary that can describe the feelings within me for you is your faith in me. I have ever known and I hope that you love me and hug me when I don’t deserve neither you nor your love.
# ...

# %%
modeljson = generator_a.to_json()
import json
# Writing a JSON file
with open('model.json', 'w') as f:
    json.dump(modeljson, f)

# %%
  
# Reading a JSON file
with open('data.json', 'r') as f:
    data = json.load(f)


reconstituted_model = mk.Text.from_json(data)
for i in range(5):
    print(reconstituted_model.make_sentence())
# Out:
# I love you and hold on to you believe me, I would do anything to rectify the wrongs all I need it the most, and the very air I breathe and a cheat.
# I know that you are that once in a way that I made a big mistake, please forgive me for you bring so much that I put to shield myself from pain, and I assure you that you were the happiest times of my life would be without you.
# And I feel today.
# Before I met you, I didn't believe it was like fireworks in the corner: the chair at the windmill upon the mountain.
# There have been worrying you and from that day that you are the one who has seen though all the pain and grief that I made a big mistake, please forgive me for you always know what unseen feelings are beneath smiles and laughter, because your love letters and notes which are unequalled in admiration, affection and passion.

# %%
text = [reconstituted_model.make_sentence() for i in range(10)]
text
# Out:
# ["I know that there's no one else could.",
#  'Not a single thing that has ever happened to me is priceless. You have always been the one who has seen though all the joys that life has to offer once again.',
#  'When I saw your pretty smile. I wish we will always be together forever and always. I love you so much.',
#  'Knowing you are the only earth we’ll ever have, and I start to worry, I get to feel your subtle touch; your pretty lips and all your body.',
#  'Not a single thing that I want you to love someone so deeply and completely, but you have always been the one who has always picked me up when I need it the most, and the miracles they can do to deserve this kind of love letters and the wise people around the world to me. Don’t be curious anymore.',
#  'There have been so great with you, it’s been a joyride all through, I will always be together forever and always. I love everything.',
# ...

# %%
with open('data.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
import requests

url = "http://0.0.0.0:8000/loveletterlong"

response = requests.request("POST", url)

print(response.text)
# Out:
# {
#   "result": [
#     "Choose to try again and it hurts me too much: looking at your picture and seeing you smile and your beautiful eyes.",
#     "You are the only earth we\u2019ll ever have, and I want you to love someone so special to have been times when my emotions got the better of me and I know that you are the most loving and forgiving heart I have caused you pain.",
#     "I see your eyes, your lips, I feel so special if you leave me, I shall never recover.",
#     "You have always been the one who has always picked me up when I looked into your eyes, it was possible to love you and your love.",
#     "I love you so much joy into my life.",
#     "I love you and I start to worry, I get to receive a poor man like me into your eyes, it was like fireworks in the skies.",
#     "If you and only you with every breath in me.",
#     "These emotional elements will ground both of you as you have been loved by someone so special and beautiful like you.",
# ...

# %%
#print(phrases[0:5][1])
worddd = []

for score,word in phrases:
    words = word
    worddd.append(words)

worddd
# Out:
# ['writing love letter',
#  'level contextual awareness',
#  'sentiment analysis',
#  'breakthrough technology',
#  'well',
#  'plagiarism',
#  'introducing',
#  'human']

# %%
import fileinput
filename = '/work/data/messages.txt'
with open('/work/data/letter.txt', 'w') as fout, fileinput.input(filename) as fin:
    for line in fin:
        fout.write(line)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1847666d-1024-4ccd-aa0a-538596f06c6f' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
